# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df=pd.read_csv('index_price.csv')

# %%
df.head()
# Out:
#    year  month  interest_rate  unemployment_rate  index_price
# 0  1924      1           3.50               5.19   534.714897
# 1  1925      1           2.86               4.36   424.911412
# 2  1926      1           3.65               5.18   582.253910
# 3  1927      1           4.52               5.81   784.797318
# 4  1928      1           2.77               5.07   321.169866

# %%
#dropping unneccessary columns
df.drop(["year","month"],axis=1,inplace=True)

# %%
df
# Out:
#       interest_rate  unemployment_rate  index_price
# 0              3.50               5.19   534.714897
# 1              2.86               4.36   424.911412
# 2              3.65               5.18   582.253910
# 3              4.52               5.81   784.797318
# 4              2.77               5.07   321.169866
# ...             ...                ...          ...
# 1195           3.44               2.83   767.901200
# 1196           2.98               3.62   541.022220
# 1197           3.55               3.49   731.564473
# 1198           3.22               5.31   435.166468
# 1199           4.36               5.10   810.947961
#
# [1200 rows x 3 columns]

# %%
import seaborn as sns

# %%
#Visualizing relationship b/w all the columns
sns.pairplot(df)

# %%
#Correlation b/w all the fields
df.corr()
# Out:
#                    interest_rate  unemployment_rate  index_price
# interest_rate           1.000000           0.014553     0.890899
# unemployment_rate       0.014553           1.000000    -0.441184
# index_price             0.890899          -0.441184     1.000000

# %%
#Closely visualizing the data points
sns.scatterplot([df['interest_rate'],df['unemployment_rate']])
plt.xlabel("interest_rate")
plt.ylabel("unemployment_rate")
# Out:
# Text(0, 0.5, 'unemployment_rate')

# %%
x=df.iloc[:,:-1]

# %%
y=df.iloc[:,[-1]]

# %%
from sklearn.model_selection import train_test_split
X_train,x_test,Y_train,y_test=train_test_split(x,y,random_state=43,test_size=0.20)

# %%
from sklearn.linear_model import LinearRegression
model=LinearRegression()

# %%
model.fit(X_train,Y_train)
# Out:
# LinearRegression()

# %%
print(y_test)
# Out:
#       index_price
# 1014  1015.060060
# 220   1029.763625
# 340    150.052945
# 1076  -192.359552
# 942    573.768595
# ...           ...
# 877    275.199035
# 928    772.501427
# 1121   644.080938
# 429   -282.115132
# 730    658.253948
#
# [240 rows x 1 columns]

# %%
y_pred=model.predict(x_test)
print(y_pred)
# Out:
# [[ 1.01535811e+03]
#  [ 1.02974948e+03]
#  [ 1.50118340e+02]
#  [-1.92509352e+02]
#  [ 5.73830020e+02]
#  [ 7.14163917e+02]
#  [ 1.09700941e+02]
#  [ 3.36900967e+02]
#  [ 4.57296751e+02]
#  [ 9.03976306e+02]
#  [ 9.82004716e-01]
#  [ 1.99554445e+02]
#  [ 3.13961284e+02]
#  [ 5.97259025e+02]
#  [ 5.17642798e+02]
#  [ 6.11801016e+02]
#  [ 2.32656094e+02]
#  [ 1.42161199e+01]
#  [ 7.55865732e+02]
#  [ 6.15611678e+02]
#  [ 1.96058822e+02]
#  [ 1.37204196e+02]
#  [ 1.65135456e+02]
#  [ 1.97752516e+02]
#  [ 4.80311745e+02]
#  [-3.09058066e+01]
#  [ 5.41382309e+02]
#  [ 2.91463801e+02]
#  [-2.19513822e+02]
#  [ 1.01195015e+02]
#  [ 6.55360942e+02]
#  [ 1.44889717e+01]
#  [ 5.64496074e+02]
#  [ 3.03670304e+01]
#  [ 1.68720385e+02]
#  [ 5.64425495e+02]
#  [ 8.04224425e+02]
#  [ 3.53432964e+02]
#  [ 1.64368551e+02]
#  [ 2.67491774e+01]
#  [ 5.01694160e+02]
#  [ 7.76843601e+02]
#  [ 3.29039514e+02]
#  [ 6.50651682e+02]
#  [ 7.13143089e+02]
#  [ 3.85405551e+02]
#  [ 5.44708382e+02]
# ...

# %%
from sklearn.metrics import mean_absolute_error,mean_squared_error,r2_score

# %%
mse=mean_squared_error(y_test,y_pred)
mae=mean_absolute_error(y_test,y_pred)
rmse=np.sqrt(mse)
print("Mean Squared error is:",mse)
print("Mean Absolute error is:",mae)
print("RMAE is:",rmse)
# Out:
# Mean Squared error is: 0.4817112749167199
# Mean Absolute error is: 0.22351748256553663
# RMAE is: 0.6940542305300933
