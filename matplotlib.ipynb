# %%
# !pip install matplotlib
# Out:
# ...
# [notice] A new release of pip is available: 24.0 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import matplotlib as mlt
import matplotlib.pyplot as plt

# %%
x=[1,2,3,4,5]
y=[2,4,6,8,10]
plt.plot(x,y)

# %%
x=[1,2,3,4,5]
y=[2,4,6,8,10]

plt.plot(x,y)
plt.xlabel('X Axis')
plt.ylabel('Y Axis')
plt.title("Practice plot")
plt.show()

# %%
x=[1,2,3,4,5]
y=[2,4,6,8,10]

plt.plot(x,y,marker='o',linestyle='--',linewidth='4',markersize=10,color='red')
plt.xlabel('X Axis')
plt.ylabel('Y Axis')
plt.title("Practice plot")
plt.grid(True)

# %%
#Multiple plots

x=[1,2,3,4,5]
y1=[1,2,9,16,25]
y2=[1,2,3,4,5]

#plot 1
plt.subplot(2,2,1)
plt.plot(x,y1,color='red')

#plot 2
plt.subplot(2,2,2)
plt.plot(x,y2,color='red')

#plot 3
plt.subplot(2,2,3)
plt.plot(x,y1,color='blue')

#plot 4
plt.subplot(2,2,4)
plt.plot(x,y2,color='green')

# %%
#Bar graph

students=['Bhoomika','Geethike','Ajay','Tejas']
marks=[90,80,70,85]

plt.bar(students,marks,color='orange')
# Out:
# <BarContainer object of 4 artists>

# %%
#Histogram



age=[1,2,3,4,5,6,7,8,9]
plt.hist(age,bins=5,edgecolor='black')
# Out:
# (array([2., 2., 1., 2., 2.]),
#  array([1. , 2.6, 4.2, 5.8, 7.4, 9. ]),
#  <BarContainer object of 5 artists>)

# %%
#Scatter plot
x=[1,2,3,4,5]
y=[1,4,9,16,25]

plt.scatter(x,y,marker='x')

# %%
#Pie chart

labels=['Study','Eating','Exercise','sleep','playing']
sizes=[30,10,10,20,30]
explode=[0.2,0,0,0,0]
colours=['red','green','blue','orange','gold']

plt.pie(sizes,labels=labels,explode=explode,autopct="%1.1f%%",shadow=True,colors=colours)
# Out:
# ([<matplotlib.patches.Wedge at 0x2346525c310>,
# ...
#  [Text(0.7641207377093499, 1.0517221582730485, 'Study'),
#   Text(-0.6465639380677015, 0.8899185771689371, 'Eating'),
#   Text(-1.0461621541481756, 0.33991873621212615, 'Exercise'),
#   Text(-0.8899184718302892, -0.6465640830538323, 'sleep'),
#   Text(0.6465640158668551, -0.8899185206445168, 'playing')],
#  [Text(0.47022814628267684, 0.6472136358603374, '30.0%'),
#   Text(-0.352671238946019, 0.48541013300123836, '10.0%'),
#   Text(-0.5706339022626412, 0.1854102197520688, '10.0%'),
#   Text(-0.485410075543794, -0.352671318029363, '20.0%'),
#   Text(0.3526712813819209, -0.4854101021697364, '30.0%')])

# %%
#Example with car sales data

# !pip install pandas
# Out:
# ...
# [notice] A new release of pip is available: 24.0 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pandas as pd
cars_data=pd.read_csv('F:\Data Science\car-sales-extended-missing-data.csv')
cars_data.head()
# Out:
#      Make Colour  Odometer (KM)  Doors    Price
# 0   Honda  White        35431.0    4.0  15323.0
# 1     BMW   Blue       192714.0    5.0  19943.0
# 2   Honda  White        84714.0    4.0  28343.0
# 3  Toyota  White       154365.0    4.0  13434.0
# 4  Nissan   Blue       181577.0    3.0  14043.0

# %%
df=cars_data.groupby('Make')['Price'].sum()
df
# Out:
# Make
# BMW       2501927.0
# Honda     4107844.0
# Nissan    2391288.0
# Toyota    5563201.0
# Name: Price, dtype: float64

# %%
df.plot(kind='bar')
plt.xlabel("Make")
plt.ylabel("Sales")
# Out:
# Text(0, 0.5, 'Sales')

# %%
#Stocks data over time
stocks_data=pd.read_csv('F:\Data Science\stock_data.csv')
stocks_data.head()
# Out:
#        Date   Open   High    Low  Close    Volume  Name
# 0  1/3/2006  39.69  41.22  38.79  40.91  24232729  AABA
# 1  1/4/2006  41.22  41.90  40.77  40.97  20553479  AABA
# 2  1/5/2006  40.93  41.73  40.85  41.53  12829610  AABA
# 3  1/6/2006  42.88  43.57  42.80  43.21  29422828  AABA
# 4  1/9/2006  43.10  43.66  42.82  43.42  16268338  AABA

# %%
data=stocks_data.groupby('Date')['Volume'].sum().reset_index()
plt.plot(data['Date'],data['Volume'])
